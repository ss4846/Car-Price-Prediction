# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('C:/Users/S.MD.OMAR/car prediction/car_purchasing.csv', encoding='ISO-8859-1')
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)
df.head()
# Out:
#          age  annual Salary  credit card debt    net worth  \
# 0  41.851720    62812.09301      11609.380910  238961.2505
# 1  40.870623    66646.89292       9572.957136  530973.9078
# 2  43.152897    53798.55112      11160.355060  638467.1773
# 3  58.271369    79370.03798      14426.164850  548599.0524
# 4  57.313749    59729.15130       5358.712177  560304.0671
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  500 non-null    float64
#  1   annual Salary        500 non-null    float64
#  2   credit card debt     500 non-null    float64
#  3   net worth            500 non-null    float64
#  4   car purchase amount  500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
plt.scatter(df['annual Salary'] , df['credit card debt'])
plt.xlabel('annual Salary')
plt.ylabel('credit card debt')
plt.title('the corr between credit card debt and annual Salary')
# Out:
# Text(0.5, 1.0, 'the corr between credit card debt and annual Salary')

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
# print(X)
# print(y)

# %%
scale = MinMaxScaler()
X = scale.fit_transform(X)
y = scale.fit_transform(y.values.reshape(-1, 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)
# print(X)
# print(y)

# %%
ann = Sequential([Dense(32, activation="relu"),
                 Dense(1, activation='linear')])

ann.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['mean_absolute_error'])


history = ann.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.4645 - mean_absolute_error: 0.6492 - val_loss: 0.3487 - val_mean_absolute_error: 0.5559
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3131 - mean_absolute_error: 0.5251 - val_loss: 0.2321 - val_mean_absolute_error: 0.4434
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1960 - mean_absolute_error: 0.4036 - val_loss: 0.1390 - val_mean_absolute_error: 0.3295
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1221 - mean_absolute_error: 0.3051 - val_loss: 0.0716 - val_mean_absolute_error: 0.2211
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0579 - mean_absolute_error: 0.1984 - val_loss: 0.0345 - val_mean_absolute_error: 0.1456
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0279 - mean_absolute_error: 0.1304 - val_loss: 0.0208 - val_mean_absolute_error: 0.1203
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0177 - mean_absolute_error: 0.1031 - val_loss: 0.0187 - val_mean_absolute_error: 0.1176
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0212 - mean_absolute_error: 0.1165 - val_loss: 0.0185 - val_mean_absolute_error: 0.1177
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0204 - mean_absolute_error: 0.1133 - val_loss: 0.0177 - val_mean_absolute_error: 0.1152
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0189 - mean_absolute_error: 0.1093 - val_loss: 0.0166 - val_mean_absolute_error: 0.1110
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0175 - mean_absolute_error: 0.1051 - val_loss: 0.0153 - val_mean_absolute_error: 0.1063
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0133 - mean_absolute_error: 0.0916 - val_loss: 0.0142 - val_mean_absolute_error: 0.1023
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0139 - mean_absolute_error: 0.0938 - val_loss: 0.0132 - val_mean_absolute_error: 0.0991
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0141 - mean_absolute_error: 0.0935 - val_loss: 0.0124 - val_mean_absolute_error: 0.0963
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0130 - mean_absolute_error: 0.0886 - val_loss: 0.0116 - val_mean_absolute_error: 0.0934
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0123 - mean_absolute_error: 0.0876 - val_loss: 0.0108 - val_mean_absolute_error: 0.0904
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0112 - mean_absolute_error: 0.0819 - val_loss: 0.0101 - val_mean_absolute_error: 0.0872
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0110 - mean_absolute_error: 0.0808 - val_loss: 0.0094 - val_mean_absolute_error: 0.0844
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - mean_absolute_error: 0.0733 - val_loss: 0.0087 - val_mean_absolute_error: 0.0815
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0089 - mean_absolute_error: 0.0745 - val_loss: 0.0082 - val_mean_absolute_error: 0.0785
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - mean_absolute_error: 0.0745 - val_loss: 0.0076 - val_mean_absolute_error: 0.0757
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - mean_absolute_error: 0.0659 - val_loss: 0.0072 - val_mean_absolute_error: 0.0732
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067 - mean_absolute_error: 0.0665 - val_loss: 0.0067 - val_mean_absolute_error: 0.0707
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0069 - mean_absolute_error: 0.0669 - val_loss: 0.0064 - val_mean_absolute_error: 0.0683
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0067 - mean_absolute_error: 0.0657 - val_loss: 0.0060 - val_mean_absolute_error: 0.0662
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0069 - mean_absolute_error: 0.0671 - val_loss: 0.0057 - val_mean_absolute_error: 0.0641
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - mean_absolute_error: 0.0593 - val_loss: 0.0054 - val_mean_absolute_error: 0.0624
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0564 - val_loss: 0.0051 - val_mean_absolute_error: 0.0604
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - mean_absolute_error: 0.0562 - val_loss: 0.0049 - val_mean_absolute_error: 0.0586
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0567 - val_loss: 0.0046 - val_mean_absolute_error: 0.0570
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - mean_absolute_error: 0.0551 - val_loss: 0.0044 - val_mean_absolute_error: 0.0550
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0560 - val_loss: 0.0042 - val_mean_absolute_error: 0.0534
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0561 - val_loss: 0.0040 - val_mean_absolute_error: 0.0521
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0507 - val_loss: 0.0038 - val_mean_absolute_error: 0.0508
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - mean_absolute_error: 0.0547 - val_loss: 0.0036 - val_mean_absolute_error: 0.0496
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - mean_absolute_error: 0.0501 - val_loss: 0.0035 - val_mean_absolute_error: 0.0483
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - mean_absolute_error: 0.0501 - val_loss: 0.0033 - val_mean_absolute_error: 0.0472
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mean_absolute_error: 0.0483 - val_loss: 0.0032 - val_mean_absolute_error: 0.0461
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - mean_absolute_error: 0.0492 - val_loss: 0.0031 - val_mean_absolute_error: 0.0446
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037 - mean_absolute_error: 0.0493 - val_loss: 0.0029 - val_mean_absolute_error: 0.0437
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mean_absolute_error: 0.0467 - val_loss: 0.0027 - val_mean_absolute_error: 0.0426
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - mean_absolute_error: 0.0470 - val_loss: 0.0026 - val_mean_absolute_error: 0.0413
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mean_absolute_error: 0.0437 - val_loss: 0.0025 - val_mean_absolute_error: 0.0405
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0424 - val_loss: 0.0024 - val_mean_absolute_error: 0.0392
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mean_absolute_error: 0.0426 - val_loss: 0.0022 - val_mean_absolute_error: 0.0385
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0418 - val_loss: 0.0021 - val_mean_absolute_error: 0.0372
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0400 - val_loss: 0.0020 - val_mean_absolute_error: 0.0367
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0382 - val_loss: 0.0019 - val_mean_absolute_error: 0.0357
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0385 - val_loss: 0.0018 - val_mean_absolute_error: 0.0341
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0383 - val_loss: 0.0017 - val_mean_absolute_error: 0.0336

# %%
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmin(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# plt.subplot(1, 2, 2)
# plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
# plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
# plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
# plt.title('Training and Validation Accuracy')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()

plt.tight_layout
plt.show()

# %%
ann_y_pred = ann.predict(X_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
ann.evaluate(X_test, y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0366
# [0.0022970344871282578, 0.03692504018545151]

# %%
ann.predict(x=np.array([[40, 70000.500, 9550,534000]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# array([[106475.27]], dtype=float32)

# %%
plt.figure(figsize=(10, 6))
# plt.scatter(y_test, y_pred, label='Linear Regression')
plt.scatter(y_test, ann_y_pred, label='ANN')
# plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='gray')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.legend()
plt.show()
